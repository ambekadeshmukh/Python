# %% [markdown]
# # Network Programming
#
# - The Internet has undeniably become the ‘Soul of Existence’ and its activity is characterized by ‘Connections’ or ‘Networks’
# - These networks are made possible using one of the most crucial fundamentals of Sockets
# - Sockets help you make these connections, while Python, undoubtedly, makes it easy
#
# # Why use Sockets?
#
# - Sockets are the backbone of networking
# - They make the transfer of information possible between two different programs or devices
# - For example, when you open up your browser, you as a client are creating a connection to the server for the transfer of information
#
# # What are Sockets?
#
# - In general terms, sockets are interior endpoints built for sending and receiving data
# - These sockets are a combination of an IP address and a Port
# - A single device can have ‘n’ number of sockets based on the port number that is being used
# - Different ports are available for different types of protocols
# - Take a look at the following image for more about some of the common port numbers and the related protocols:
#
# ![image.png](attachment:image.png)
#
# # How to achieve Socket Programming in Python:
#
# - To achieve Socket Programming in Python, you will need to import the socket module
# - This module consists of built-in methods that are required for creating sockets and help them associate with each other
#
# **socket.socket()** - used to create sockets (required on both server as well as client ends to create sockets)
#
# **AF_INET** refers to Address from the Internet and it requires a pair of (host, port) where the host can either be a URL of some particular website or its address and the port number is an integer
#
# **SOCK_STREAM** is used to create TCP Protocols

# %%
import socket
s=socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# %% [markdown]
# **socket.bind()** - used to bind to the address that is specified as a parameter

# %%
s.bind((socket.gethostname(),1234))          
# port number can be anything between 0-65535(we usually specify non-previleged ports which are > 1023)

# %% [markdown]
# **socket.listen()** - enables the server to accept connections

# %%
s.listen()

# %% [markdown]
# socket.accept() - used to accept a connection
# - It returns a pair of values (conn, address) where conn is a new socket object for sending or receiving data and address is the address of the socket present at the other end of the connection

# %%
a = 1
while a < 2:
    clt,adr=s.accept()
    print(f"Connection to {adr}established")  
   #f string is literal string prefixed with f which 
   #contains python expressions inside braces
    clt.send(bytes("Socket Programming in Python","utf-8 ")) #to send info to clientsocket
    a = a + 1
# Out:
# Connection to ('192.168.0.100', 64854)established

# %% [markdown]
# # [Resource](https://www.edureka.co/blog/socket-programming-python/)
